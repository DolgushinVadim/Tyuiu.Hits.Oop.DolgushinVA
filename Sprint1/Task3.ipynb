// %% [markdown]
// <h1 style="color:DodgerBlue">Индивидальный проект</h1>

// %% [markdown]
// <h2 style="color:DodgerBlue">Название проекта:</h2>
//
// ----
//
// ### Вариант задания 5

// %% [markdown]
// <h2 style="color:DodgerBlue">Описание проекта:</h2>
//
// ----
//
// Описание задачи:
//
// Создать базовый класс Book в C#, который будет представлять информацию о
// книгах. На основе этого класса разработать 2-3 производных класса,
// демонстрирующих принципы наследования и полиморфизма. В каждом из классов
// должны быть реализованы новые атрибуты и методы, а также переопределены
// некоторые методы базового класса для демонстрации полиморфизма.
//
// Требования к базовому классу Book:
//
// • Атрибуты: Название (Title), Автор (Author), Год издания (YearOfPublication).
//
// • Методы:
//
// o GetInfo(): метод для получения информации о книге в виде строки.
//
// o Read(): метод для вывода сообщения о чтении книги.
//
// o Borrow(): метод для вывода сообщения о выдаче книги на чтение.
//
// <h2 style="color:DodgerBlue">Требования к производным классам:</h2>
//
// ----
//
// 1. Учебник (Textbook): Должен содержать дополнительные атрибуты, такие как
// Предмет (Subject). Метод Read() должен быть переопределен для
// добавления информации о предмете при чтении учебника.
//
// 2. Художественная литература (Fiction): Должен содержать дополнительные
// атрибуты, такие как Жанр (Genre). Метод Borrow() должен быть
// переопределен для добавления информации о жанре при выдаче книги на
// чтение.
//
// 3. Научная литература (ScientificLiterature) (если требуется третий класс):
// Должен содержать дополнительные атрибуты, такие как Область науки
// (FieldOfScience). Метод GetInfo() должен быть переопределен для включения
// информации об области науки в описании книги.
//
// #### Дополнительное задание
// Добавьте к сущестующим классам конструктора классов с использованием гетторов и сетторов и реализуйте взаимодействие объектов между собой

// %% [markdown]
// <h2 style="color:DodgerBlue">Реализация:</h2>
//
// ----

// %%
using System;

public interface IBook 
{
    string Title { get; set; }
    string Author { get; set; }
    int YearOfPublication { get; set; }

    void GetInfo();
    void Read();
    void Borrow();
}

public interface ITextbook
{
    string Subject { get; set; }
}

public interface IFiction 
{
    string Genre { get; set; }
}

public interface IScientificLiterature 
{
    string FieldOfScience { get; set; }
}

public class Book : IBook
{
    public string Title { get; set; }
    public string Author { get; set; }
    public int YearOfPublication { get; set; }

    public Book(string title, string author, int yearOfPublication) 
    {
        Title = title;
        Author = author;
        YearOfPublication = yearOfPublication;
    }

    public virtual void GetInfo() 
    {
        Console.WriteLine($"Название: {Title}, Автор: {Author}, Год издания: {YearOfPublication}");
    }

    public virtual void Read() 
    {
        Console.WriteLine($"Вы прочитали книгу '{Title}'");
    }

    public virtual void Borrow() 
    {
        Console.WriteLine($"Вам выдали книгу '{Title}'");
    }
}

public class Textbook : Book, ITextbook 
{
    public string Subject { get; set; }

    public Textbook(string title, string author, int yearOfPublication, string subject)
        : base(title, author, yearOfPublication) 
    {
        Subject = subject;
    }

    public override void Read() 
    {
        Console.WriteLine($"Вы читаете учебник '{Title}' по предмету '{Subject}'");
    }
}

public class Fiction : Book, IFiction 
{
    public string Genre { get; set; }

    public Fiction(string title, string author, int yearOfPublication, string genre)
        : base(title, author, yearOfPublication)
    {
        Genre = genre;
    }

    public override void Borrow()
    {
        Console.WriteLine($"Вам выдали художественную книгу '{Title}', жанр которой '{Genre}'");
    }
}

public class ScientificLiterature : Book, IScientificLiterature 
{
    public string FieldOfScience { get; set; }

    public ScientificLiterature(string title, string author, int yearOfPublication, string fieldOfScience)
        : base(title, author, yearOfPublication)
    {
        FieldOfScience = fieldOfScience;
    }

    public override void GetInfo() 
    {
        Console.WriteLine($"Название: {Title}, Автор: {Author}, Год издания: {YearOfPublication}, Область науки: {FieldOfScience}");
    }
}

Textbook mathTextbook = new Textbook("Алгебра и начала математического анализа 11 класс", "Колягин Ю. М.", 2014, "Математика");
Fiction novel = new Fiction("Война и мир", "Толстой Л.Н.", 1869, "Исторический роман");
ScientificLiterature physicsBook = new ScientificLiterature("Классическая механика", "Ньютон И.С.", 1687, "Физика");

mathTextbook.GetInfo();
mathTextbook.Read();
mathTextbook.Borrow();

novel.GetInfo();
novel.Read();
novel.Borrow();

physicsBook.GetInfo();
physicsBook.Read();
physicsBook.Borrow();
// Out:
// Название: Алгебра и начала математического анализа 11 класс, Автор: Колягин Ю. М., Год издания: 2014
// Вы читаете учебник 'Алгебра и начала математического анализа 11 класс' по предмету 'Математика'
// Вам выдали книгу 'Алгебра и начала математического анализа 11 класс'
// Название: Война и мир, Автор: Толстой Л.Н., Год издания: 1869
// Вы прочитали книгу 'Война и мир'
// Вам выдали художественную книгу 'Война и мир', жанр которой 'Исторический роман'
// Название: Классическая механика, Автор: Ньютон И.С., Год издания: 1687, Область науки: Физика
// Вы прочитали книгу 'Классическая механика'
// Вам выдали книгу 'Классическая механика'
